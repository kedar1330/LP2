# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\pooja\Downloads\StudentsPerformance - StudentsPerformance.csv")

# %%
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(df['math score'])
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
print(df['math score'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
print(df['reading score'])
# Out:
# 0      72
# 1      90
# 2      95
# 3      57
# 4      78
#        ..
# 995    99
# 996    55
# 997    71
# 998    78
# 999    86
# Name: reading score, Length: 1000, dtype: int64

# %%
print(df['reading score'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: reading score, Length: 1000, dtype: bool

# %%
print()

# %%
missing_values = ["n/a", "na", "--"]
df = pd.read_csv(r"C:\Users\pooja\Downloads\StudentsPerformance - StudentsPerformance.csv", na_values=missing_values)

# %%
print(df.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72            NaN
# 1               completed          69             90           88.0
# 2                    none          90             95           93.0
# 3                    none          47             57           44.0
# 4                    none          76             78           75.0

# %%
print(df['reading score'])
# Out:
# 0      72
# 1      90
# 2      95
# 3      57
# 4      78
#        ..
# 995    99
# 996    55
# 997    71
# 998    78
# 999    86
# Name: reading score, Length: 1000, dtype: int64

# %%
print(df['reading score'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: reading score, Length: 1000, dtype: bool

# %%
dataset = [11,41,20,3,101,55,68,97,99,6]

# %%
sorted(dataset)
# Out:
# [3, 6, 11, 20, 41, 55, 68, 97, 99, 101]

# %%
quantile1, quantile3 = np.percentile(dataset, [25,75])

# %%
print(quantile1, quantile3)
# Out:
# 13.25 89.75

# %%
iqr_value = (quantile3 - quantile1)

# %%
print(iqr_value)
# Out:
# 76.5

# %%
lower_bound_value = quantile1 - (1.5*iqr_value)

# %%
upper_bound_value = quantile3 - (1.5*iqr_value)

# %%
print(lower_bound_value, upper_bound_value)
# Out:
# -101.5 -25.0

# %%
print(df.columns)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']

# %%
df['average_score'] = df['total_score'] / 3

# %%
df['math_score_scaled'] = (df['math score'] - df['math score'].min()) / (df['math score'].max() - df['math score'].min())

# %%
df['math_score_log'] = np.log1p(df['math score'])

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72            NaN
# 1               completed          69             90           88.0
# 2                    none          90             95           93.0
# 3                    none          47             57           44.0
# 4                    none          76             78           75.0
#
#    total_score  average_score  math_score_scaled  math_score_log
# 0          NaN            NaN               0.72        4.290459
# ...
